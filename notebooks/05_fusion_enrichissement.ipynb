# %% [markdown]
# # Etape 2.2 : Fusion et enrichissement

# %% [markdown]
# ## Charger les consommations nettoyees (depuis Parquet)

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# Configuration affichage
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# Chemins
DATA_DIR = "../data"
OUTPUT_DIR = "../data/output"
PARQUET_DIR = "../data/output/consommations_clean"

# %%
# chargement des données
df_consommations = pd.read_parquet(PARQUET_DIR, engine='fastparquet')
print(f"Données chargées : {len(df_consommations):,} lignes")


df_consommations.head(5)
# Out:
# exist
# Données chargées : 6,996,788 lignes
#   batiment_id            timestamp consommation unite    timestamp_parsed  \
# 0     BAT0001  2023-01-01 02:00:00         0.20    m3 2023-01-01 02:00:00
# 1     BAT0139     01/01/2023 18:00        78.93    m3 2023-01-01 18:00:00
# 2     BAT0001  2023-01-01 17:00:00         2.60    m3 2023-01-01 17:00:00
# 3     BAT0139     01/01/2023 22:00       121.29    m3 2023-01-01 22:00:00
# 4     BAT0001  01/01/2023 21:00:00         1.85    m3 2023-01-01 21:00:00
#
#    consommation_clean  hour  year  month commune       date type_energie
# 0                0.20     2  2023      1   Paris 2023-01-01          eau
# 1               78.93    18  2023      1  Toulon 2023-01-01          eau
# 2                2.60    17  2023      1   Paris 2023-01-01          eau
# 3              121.29    22  2023      1  Toulon 2023-01-01          eau
# 4                1.85    21  2023      1   Paris 2023-01-01          eau

# %% [markdown]
# ### - Fusionner avec les donnees meteo (sur commune et timestamp arrondi a l'heure)

# %%
df_meteo = pd.read_csv("../data/output/meteo_clean.csv" , sep=",")
df_meteo.head(5)
df_join_meteo = pd.merge(
    df_consommations, 
    df_meteo, 
    on=["commune", "timestamp", "month"], 
    how="inner"
)

df_join_meteo.head(5)
# Out:
#   batiment_id            timestamp consommation unite    timestamp_parsed  \
# 0     BAT0001  2023-01-01 17:00:00         2.60    m3 2023-01-01 17:00:00
# 1     BAT0002  2023-01-01 09:00:00         1.04    m3 2023-01-01 09:00:00
# 2     BAT0140  2023-01-01 13:00:00        23.30    m3 2023-01-01 13:00:00
# 3     BAT0003  2023-01-01 03:00:00         0.15    m3 2023-01-01 03:00:00
# 4     BAT0003  2023-01-01 10:00:00         1.74    m3 2023-01-01 10:00:00
#
#    consommation_clean  hour  year  month commune       date type_energie  \
# 0                2.60    17  2023      1   Paris 2023-01-01          eau
# 1                1.04     9  2023      1   Paris 2023-01-01          eau
# 2               23.30    13  2023      1  Toulon 2023-01-01          eau
# 3                0.15     3  2023      1   Paris 2023-01-01          eau
# 4                1.74    10  2023      1   Paris 2023-01-01          eau
#
#    temperature_c  humidite_pct  rayonnement_solaire_wm2  vitesse_vent_kmh  \
# 0           78.3          78.3                    534.3              32.0
# 1           49.7          49.7                     36.2              18.1
# 2           60.4          60.4                    764.9              16.2
# 3           59.7          59.7                     35.4              25.4
# 4           84.8          84.8                    582.7              13.3
#
#    precipitation_mm  day  season  weekday
# 0               0.0    1       1        6
# 1               0.0    1       1        6
# 2               4.2    1       1        6
# 3               0.0    1       1        6
# 4               0.0    1       1        6

# %% [markdown]
# ### - Fusionner avec le referentiel batiments

# %%
df_batiments = pd.read_csv("../data/batiments.csv" , sep=",")
df_batiments.head(5)
df_join_batiments = df_join_meteo.merge(
    df_batiments,
    on=['commune','batiment_id'],
    how='left'
)

df_join_batiments.head(5)
# Out:
#   batiment_id            timestamp consommation unite    timestamp_parsed  \
# 0     BAT0001  2023-01-01 17:00:00         2.60    m3 2023-01-01 17:00:00
# 1     BAT0002  2023-01-01 09:00:00         1.04    m3 2023-01-01 09:00:00
# 2     BAT0140  2023-01-01 13:00:00        23.30    m3 2023-01-01 13:00:00
# 3     BAT0003  2023-01-01 03:00:00         0.15    m3 2023-01-01 03:00:00
# 4     BAT0003  2023-01-01 10:00:00         1.74    m3 2023-01-01 10:00:00
#
#    consommation_clean  hour  year  month commune       date type_energie  \
# 0                2.60    17  2023      1   Paris 2023-01-01          eau
# 1                1.04     9  2023      1   Paris 2023-01-01          eau
# 2               23.30    13  2023      1  Toulon 2023-01-01          eau
# 3                0.15     3  2023      1   Paris 2023-01-01          eau
# 4                1.74    10  2023      1   Paris 2023-01-01          eau
#
#    temperature_c  humidite_pct  rayonnement_solaire_wm2  vitesse_vent_kmh  \
# 0           78.3          78.3                    534.3              32.0
# 1           49.7          49.7                     36.2              18.1
# 2           60.4          60.4                    764.9              16.2
# 3           59.7          59.7                     35.4              25.4
# 4           84.8          84.8                    582.7              13.3
#
#    precipitation_mm  day  season  weekday                 nom     type  \
# 0               0.0    1       1        6       Ecole Paris 1    ecole
# 1               0.0    1       1        6       Ecole Paris 2    ecole
# 2               4.2    1       1        6  Gymnase Toulon 140  gymnase
# 3               0.0    1       1        6       Ecole Paris 3    ecole
# 4               0.0    1       1        6       Ecole Paris 3    ecole
#
#    surface_m2  annee_construction classe_energetique  nb_occupants_moyen
# 0        1926                1978                  E                 225
# 1        1156                2004                  C                 402
# 2        1697                1985                  F                 121
# 3        1695                2014                  D                 219
# 4        1695                2014                  D                 219

# %% [markdown]
# ### - Fusionner avec les tarifs pour calculer le cout financier

# %%
df_tarifs = pd.read_csv("../data/tarifs_energie.csv" , sep=",")
df_tarifs.head(5)

df_join_batiments['date'] = pd.to_datetime(df_join_batiments['date'])
df_tarifs['date_debut'] = pd.to_datetime(df_tarifs['date_debut'])
df_tarifs['date_fin'] = pd.to_datetime(df_tarifs['date_fin'])

df_final = df_join_batiments.merge(
    df_tarifs,
    on='type_energie',
    how='left'
)

# df_final = df_join_batiments.merge(
#     df_tarifs,
#     on=['commune','batiment_id'],
#     how='left'
# )

df_final.head(5)
# Out:
#   batiment_id            timestamp consommation unite    timestamp_parsed  \
# 0     BAT0001  2023-01-01 17:00:00         2.60    m3 2023-01-01 17:00:00
# 1     BAT0001  2023-01-01 17:00:00         2.60    m3 2023-01-01 17:00:00
# 2     BAT0002  2023-01-01 09:00:00         1.04    m3 2023-01-01 09:00:00
# 3     BAT0002  2023-01-01 09:00:00         1.04    m3 2023-01-01 09:00:00
# 4     BAT0140  2023-01-01 13:00:00        23.30    m3 2023-01-01 13:00:00
#
#    consommation_clean  hour  year  month commune       date type_energie  \
# 0                2.60    17  2023      1   Paris 2023-01-01          eau
# 1                2.60    17  2023      1   Paris 2023-01-01          eau
# 2                1.04     9  2023      1   Paris 2023-01-01          eau
# 3                1.04     9  2023      1   Paris 2023-01-01          eau
# 4               23.30    13  2023      1  Toulon 2023-01-01          eau
#
#    temperature_c  humidite_pct  rayonnement_solaire_wm2  vitesse_vent_kmh  \
# 0           78.3          78.3                    534.3              32.0
# 1           78.3          78.3                    534.3              32.0
# 2           49.7          49.7                     36.2              18.1
# 3           49.7          49.7                     36.2              18.1
# 4           60.4          60.4                    764.9              16.2
#
#    precipitation_mm  day  season  weekday                 nom     type  \
# 0               0.0    1       1        6       Ecole Paris 1    ecole
# 1               0.0    1       1        6       Ecole Paris 1    ecole
# 2               0.0    1       1        6       Ecole Paris 2    ecole
# 3               0.0    1       1        6       Ecole Paris 2    ecole
# 4               4.2    1       1        6  Gymnase Toulon 140  gymnase
#
#    surface_m2  annee_construction classe_energetique  nb_occupants_moyen  \
# 0        1926                1978                  E                 225
# 1        1926                1978                  E                 225
# 2        1156                2004                  C                 402
# 3        1156                2004                  C                 402
# 4        1697                1985                  F                 121
#
#   date_debut   date_fin  tarif_unitaire
# 0 2023-01-01 2023-12-31            3.50
# 1 2024-01-01 2024-12-31            3.75
# 2 2023-01-01 2023-12-31            3.50
# 3 2024-01-01 2024-12-31            3.75
# 4 2023-01-01 2023-12-31            3.50

# %% [markdown]
# ### Creer des features derivees :

# %% [markdown]
#   - Consommation par occupant

# %%
df_final['consommation_par_occupant'] = df_final['consommation_clean'] / df_final['nb_occupants_moyen']

# %% [markdown]
#   - Consommation par m2

# %%
df_final['consommation_par_m2'] = df_final['consommation_clean'] / df_final['surface_m2']

# %% [markdown]
#   - Cout journalier, mensuel, annuel

# %%
df_final['cout_instantane'] = df_final['consommation_clean'] * df_final['tarif_unitaire']
costs = df_final.groupby('batiment_id')['cout_instantane'].agg(['sum', 'mean'])

# %% [markdown]
#   - Indice de performance energetique (IPE)

# %%
conso_annuelle = df_final.groupby('batiment_id')['consommation_clean'].transform('sum')
df_final['IPE'] = conso_annuelle / df_final['surface_m2']

# %% [markdown]
#   - Ecart a la moyenne de la categorie

# %%
df_final['moyenne_type'] = df_final.groupby('type')['consommation_par_m2'].transform('mean')

df_final['ecart_moyenne_categorie_pct'] = ((df_final['consommation_par_m2'] - df_final['moyenne_type']) / df_final['moyenne_type']) * 100

# %%
df_final.head(5)
# Out:
#   batiment_id            timestamp consommation unite    timestamp_parsed  \
# 0     BAT0001  2023-01-01 17:00:00         2.60    m3 2023-01-01 17:00:00
# 1     BAT0001  2023-01-01 17:00:00         2.60    m3 2023-01-01 17:00:00
# 2     BAT0002  2023-01-01 09:00:00         1.04    m3 2023-01-01 09:00:00
# 3     BAT0002  2023-01-01 09:00:00         1.04    m3 2023-01-01 09:00:00
# 4     BAT0140  2023-01-01 13:00:00        23.30    m3 2023-01-01 13:00:00
#
#    consommation_clean  hour  year  month commune       date type_energie  \
# 0                2.60    17  2023      1   Paris 2023-01-01          eau
# 1                2.60    17  2023      1   Paris 2023-01-01          eau
# 2                1.04     9  2023      1   Paris 2023-01-01          eau
# 3                1.04     9  2023      1   Paris 2023-01-01          eau
# 4               23.30    13  2023      1  Toulon 2023-01-01          eau
#
#    temperature_c  humidite_pct  rayonnement_solaire_wm2  vitesse_vent_kmh  \
# 0           78.3          78.3                    534.3              32.0
# 1           78.3          78.3                    534.3              32.0
# 2           49.7          49.7                     36.2              18.1
# 3           49.7          49.7                     36.2              18.1
# 4           60.4          60.4                    764.9              16.2
#
#    precipitation_mm  day  season  weekday                 nom     type  \
# 0               0.0    1       1        6       Ecole Paris 1    ecole
# 1               0.0    1       1        6       Ecole Paris 1    ecole
# 2               0.0    1       1        6       Ecole Paris 2    ecole
# 3               0.0    1       1        6       Ecole Paris 2    ecole
# 4               4.2    1       1        6  Gymnase Toulon 140  gymnase
#
#    surface_m2  annee_construction classe_energetique  nb_occupants_moyen  \
# 0        1926                1978                  E                 225
# 1        1926                1978                  E                 225
# 2        1156                2004                  C                 402
# 3        1156                2004                  C                 402
# 4        1697                1985                  F                 121
#
#   date_debut   date_fin  tarif_unitaire  consommation_par_occupant  \
# 0 2023-01-01 2023-12-31            3.50                   0.011556
# 1 2024-01-01 2024-12-31            3.75                   0.011556
# 2 2023-01-01 2023-12-31            3.50                   0.002587
# 3 2024-01-01 2024-12-31            3.75                   0.002587
# 4 2023-01-01 2023-12-31            3.50                   0.192562
#
#    consommation_par_m2  cout_instantane          IPE  moyenne_type  \
# 0              0.00135             9.10  2932.126282      0.084182
# 1              0.00135             9.75  2932.126282      0.084182
# 2              0.00090             3.64  2046.317993      0.084182
# 3              0.00090             3.90  2046.317993      0.084182
# 4              0.01373            81.55  6197.985386      0.137677
#
#    ecart_moyenne_categorie_pct
# 0                   -98.396390
# 1                   -98.396390
# 2                   -98.931296
# 3                   -98.931296
# 4                   -90.027272

# %%
# Exporter le fichier
df_final.to_csv('../data/output/consommations_enrichies.csv', index=False)
